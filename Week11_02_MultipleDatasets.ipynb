# %% [markdown]
# ## Example: Analyzing Airport Operations
#
# For this project, we will use `airports.csv`, `airport-frequencies.csv`, `countries.csv`, `regions.csv` from [OurAirports.com](https://ourairports.com/data/).
#
# Instead of downloading the files, we can directly load the data through their URLs.

# %%
import numpy as np
import pandas as pd

# %%
# Load the datasets
airports = pd.read_csv("https://ourairports.com/data/airports.csv", sep=",")
airports.head()
# Out:
#        id ident           type                  name  latitude_deg  \
# 0    6523   00A       heliport     Total RF Heliport     40.070985
# 1  323361  00AA  small_airport  Aero B Ranch Airport     38.704022
# 2    6524  00AK  small_airport          Lowell Field     59.947733
# 3    6525  00AL  small_airport          Epps Airpark     34.864799
# 4  506791  00AN  small_airport  Katmai Lodge Airport     59.093287
#
#    longitude_deg  elevation_ft continent iso_country iso_region  municipality  \
# 0     -74.933689          11.0       NaN          US      US-PA      Bensalem
# 1    -101.473911        3435.0       NaN          US      US-KS         Leoti
# 2    -151.692524         450.0       NaN          US      US-AK  Anchor Point
# 3     -86.770302         820.0       NaN          US      US-AL       Harvest
# 4    -156.456699          80.0       NaN          US      US-AK   King Salmon
#
#   scheduled_service gps_code iata_code local_code  \
# 0                no     K00A       NaN        00A
# 1                no     00AA       NaN       00AA
# 2                no     00AK       NaN       00AK
# 3                no     00AL       NaN       00AL
# 4                no     00AN       NaN       00AN
#
#                                            home_link wikipedia_link keywords
# 0  https://www.penndot.pa.gov/TravelInPA/airports...            NaN      NaN
# 1                                                NaN            NaN      NaN
# 2                                                NaN            NaN      NaN
# 3                                                NaN            NaN      NaN
# 4                                                NaN            NaN      NaN

# %%
print("Size:\n", airports.shape)
print("Data types:\n", airports.dtypes)
# Out:
# Size:
#  (77024, 18)
# Data types:
#  id                     int64
# ident                 object
# type                  object
# name                  object
# latitude_deg         float64
# longitude_deg        float64
# elevation_ft         float64
# continent             object
# iso_country           object
# iso_region            object
# municipality          object
# scheduled_service     object
# gps_code              object
# iata_code             object
# local_code            object
# home_link             object
# wikipedia_link        object
# keywords              object
# dtype: object

# %%
airports.isnull().sum()
# Out:
# id                       0
# ident                    0
# type                     0
# name                     0
# latitude_deg             0
# longitude_deg            0
# elevation_ft         14407
# continent            37094
# iso_country            259
# iso_region               0
# municipality          4924
# scheduled_service        0
# gps_code             35364
# iata_code            68124
# local_code           44155
# home_link            73291
# wikipedia_link       65929
# keywords             59561
# dtype: int64

# %%
# Load other csv files
airport_freq = pd.read_csv("https://ourairports.com/data/airport-frequencies.csv", sep=',')
countries = pd.read_csv("https://ourairports.com/data/countries.csv", sep=',')
regions = pd.read_csv("https://ourairports.com/data/regions.csv", sep=',')

# %%
def basic_info(df):
    print("Size:")
    print(df.shape)
    print("="*20)
    print("Data types:")
    print(df.dtypes)
    print("="*20)
    print("Missing Values:")
    print(df.isnull().sum())
    print(df.head())

# %%
basic_info(airport_freq)
# Out:
# Size:
# (29318, 6)
# ====================
# Data types:
# id                 int64
# airport_ref        int64
# airport_ident     object
# type              object
# description       object
# frequency_mhz    float64
# dtype: object
# ====================
# Missing Values:
# id                 0
# airport_ref        0
# airport_ident      0
# type               0
# description      984
# frequency_mhz      0
# dtype: int64
#        id  airport_ref airport_ident   type          description  \
# 0   70518         6528          00CA   CTAF                 CTAF
# 1  307581         6589          01FL  ARCAL                  NaN
# 2   75239         6589          01FL   CTAF  CEDAR KNOLL TRAFFIC
# 3   60191         6756          04CA   CTAF                 CTAF
# 4   59287         6779          04MS   UNIC               UNICOM
#
#    frequency_mhz
# 0          122.9
# 1          122.9
# 2          122.8
# 3          122.9
# 4          122.8

# %%
basic_info(countries)
# Out:
# Size:
# (248, 6)
# ====================
# Data types:
# id                 int64
# code              object
# name              object
# continent         object
# wikipedia_link    object
# keywords          object
# dtype: object
# ====================
# Missing Values:
# id                 0
# code               1
# name               0
# continent         41
# wikipedia_link     0
# keywords          16
# dtype: int64
#        id code                  name continent  \
# 0  302672   AD               Andorra        EU
# 1  302618   AE  United Arab Emirates        AS
# 2  302619   AF           Afghanistan        AS
# 3  302722   AG   Antigua and Barbuda       NaN
# 4  302723   AI              Anguilla       NaN
#
#                                       wikipedia_link  \
# 0              https://en.wikipedia.org/wiki/Andorra
# 1  https://en.wikipedia.org/wiki/United_Arab_Emir...
# 2          https://en.wikipedia.org/wiki/Afghanistan
# 3  https://en.wikipedia.org/wiki/Antigua_and_Barbuda
# 4             https://en.wikipedia.org/wiki/Anguilla
#
#                                  keywords
# 0                       Andorran airports
# 1  UAE,مطارات في الإمارات العربية المتحدة
# 2                                     NaN
# 3                       Antiguan airports
# 4                                     NaN

# %%
basic_info(regions)
# Out:
# Size:
# (3927, 8)
# ====================
# Data types:
# id                 int64
# code              object
# local_code        object
# name              object
# continent         object
# iso_country       object
# wikipedia_link    object
# keywords          object
# dtype: object
# ====================
# Missing Values:
# id                  0
# code                0
# local_code          4
# name                0
# continent         433
# iso_country        15
# wikipedia_link    264
# keywords           97
# dtype: int64
#        id   code local_code                        name continent iso_country  \
# 0  302811  AD-02         02              Canillo Parish        EU          AD
# 1  302812  AD-03         03               Encamp Parish        EU          AD
# 2  302813  AD-04         04           La Massana Parish        EU          AD
# 3  302814  AD-05         05               Ordino Parish        EU          AD
# 4  302815  AD-06         06  Sant Julià de Lòria Parish        EU          AD
#
#                                       wikipedia_link  \
# 0              https://en.wikipedia.org/wiki/Canillo
# 1               https://en.wikipedia.org/wiki/Encamp
# 2           https://en.wikipedia.org/wiki/La_Massana
# 3               https://en.wikipedia.org/wiki/Ordino
# 4  https://en.wikipedia.org/wiki/Sant_Julià_de_Lòria
#
#                                  keywords
# 0              Airports in Canillo Parish
# 1               Airports in Encamp Parish
# 2           Airports in La Massana Parish
# 3               Airports in Ordino Parish
# 4  Airports in Sant Julià de Lòria Parish

# %%
# Check for duplicated records
print(airports.duplicated().sum())
print(airport_freq.duplicated().sum())
print(countries.duplicated().sum())
print(regions.duplicated().sum())
# Out:
# 0
# 0
# 0
# 0

# %% [markdown]
# #### 1. Select data with multiple conditions

# %%
# Find the region code for New York from region data frame.

regions.head()
# Out:
#        id   code local_code                        name continent iso_country  \
# 0  302811  AD-02         02              Canillo Parish        EU          AD
# 1  302812  AD-03         03               Encamp Parish        EU          AD
# 2  302813  AD-04         04           La Massana Parish        EU          AD
# 3  302814  AD-05         05               Ordino Parish        EU          AD
# 4  302815  AD-06         06  Sant Julià de Lòria Parish        EU          AD
#
#                                       wikipedia_link  \
# 0              https://en.wikipedia.org/wiki/Canillo
# 1               https://en.wikipedia.org/wiki/Encamp
# 2           https://en.wikipedia.org/wiki/La_Massana
# 3               https://en.wikipedia.org/wiki/Ordino
# 4  https://en.wikipedia.org/wiki/Sant_Julià_de_Lòria
#
#                                  keywords
# 0              Airports in Canillo Parish
# 1               Airports in Encamp Parish
# 2           Airports in La Massana Parish
# 3               Airports in Ordino Parish
# 4  Airports in Sant Julià de Lòria Parish

# %%
countries.head()
# Out:
#        id code                  name continent  \
# 0  302672   AD               Andorra        EU
# 1  302618   AE  United Arab Emirates        AS
# 2  302619   AF           Afghanistan        AS
# 3  302722   AG   Antigua and Barbuda       NaN
# 4  302723   AI              Anguilla       NaN
#
#                                       wikipedia_link  \
# 0              https://en.wikipedia.org/wiki/Andorra
# 1  https://en.wikipedia.org/wiki/United_Arab_Emir...
# 2          https://en.wikipedia.org/wiki/Afghanistan
# 3  https://en.wikipedia.org/wiki/Antigua_and_Barbuda
# 4             https://en.wikipedia.org/wiki/Anguilla
#
#                                  keywords
# 0                       Andorran airports
# 1  UAE,مطارات في الإمارات العربية المتحدة
# 2                                     NaN
# 3                       Antiguan airports
# 4                                     NaN

# %%
countries[countries['name'] == 'United States'] # This tells us that the country code for United States is US
# Out:
#          id code           name continent  \
# 229  302755   US  United States       NaN
#
#                                   wikipedia_link           keywords
# 229  https://en.wikipedia.org/wiki/United_States  American airports

# %%
regions[(regions['iso_country'] == "US") & (regions['local_code'] == "NY")]
# Out:
#           id   code local_code      name continent iso_country  \
# 3744  306110  US-NY         NY  New York       NaN          US
#
#                               wikipedia_link              keywords
# 3744  https://en.wikipedia.org/wiki/New_York  Airports in New York

# %%
regions[(regions['iso_country'] == "US") & (regions['name'] == "New York")]
# Out:
#           id   code local_code      name continent iso_country  \
# 3744  306110  US-NY         NY  New York       NaN          US
#
#                               wikipedia_link              keywords
# 3744  https://en.wikipedia.org/wiki/New_York  Airports in New York

# %%
# Extract all large airports in New York state from airoprts data frame

airports.head()
# Out:
#        id ident           type                  name  latitude_deg  \
# 0    6523   00A       heliport     Total RF Heliport     40.070985
# 1  323361  00AA  small_airport  Aero B Ranch Airport     38.704022
# 2    6524  00AK  small_airport          Lowell Field     59.947733
# 3    6525  00AL  small_airport          Epps Airpark     34.864799
# 4  506791  00AN  small_airport  Katmai Lodge Airport     59.093287
#
#    longitude_deg  elevation_ft continent iso_country iso_region  municipality  \
# 0     -74.933689          11.0       NaN          US      US-PA      Bensalem
# 1    -101.473911        3435.0       NaN          US      US-KS         Leoti
# 2    -151.692524         450.0       NaN          US      US-AK  Anchor Point
# 3     -86.770302         820.0       NaN          US      US-AL       Harvest
# 4    -156.456699          80.0       NaN          US      US-AK   King Salmon
#
#   scheduled_service gps_code iata_code local_code  \
# 0                no     K00A       NaN        00A
# 1                no     00AA       NaN       00AA
# 2                no     00AK       NaN       00AK
# 3                no     00AL       NaN       00AL
# 4                no     00AN       NaN       00AN
#
#                                            home_link wikipedia_link keywords
# 0  https://www.penndot.pa.gov/TravelInPA/airports...            NaN      NaN
# 1                                                NaN            NaN      NaN
# 2                                                NaN            NaN      NaN
# 3                                                NaN            NaN      NaN
# 4                                                NaN            NaN      NaN

# %%
# Using the iso-code "US-NY", we can extract all airport in 
# New York State
airports[airports['iso_region'] == "US-NY"]
# Out:
#            id    ident           type                                  name  \
# 37     321919     00NK  seaplane_base             Cliche Cove Seaplane Base
# 39       6554     00NY  small_airport                        Weiss Airfield
# 110      6616     01NY       heliport              Vassar Hospital Heliport
# 177      6672     02NY       heliport                       Hansen Heliport
# 245      6732     03NY  small_airport                         Talmage Field
# ...       ...      ...            ...                                   ...
# 71515  511814  US-8134       heliport               Clover Stadium Heliport
# 71545  514365  US-8164       heliport           Massena Substation Heliport
# 71556  514709  US-8175       heliport                 Wynn Hospital Helipad
# 71565   38690   US-BPA         closed              Grumman Bethpage Airport
# 73133   25591      W57  small_airport  Round Lake Airport and Seaplane Base
#
#        latitude_deg  longitude_deg  elevation_ft continent iso_country  \
# 37        44.811861     -73.369806          96.0       NaN          US
# 39        42.895760     -77.495263        1000.0       NaN          US
# 110       41.692415     -73.936830         100.0       NaN          US
# 177       43.132599     -75.655502         435.0       NaN          US
# 245       40.958308     -72.717326          95.0       NaN          US
# ...             ...            ...           ...       ...         ...
# 71515     41.170806     -74.037556         473.0       NaN          US
# 71545     44.921495     -74.834651         239.0       NaN          US
# 71556     43.104244     -75.236025         487.0       NaN          US
# 71565     40.749401     -73.496002         115.0       NaN          US
# 73133     42.929199     -73.770401         175.0       NaN          US
#
#       iso_region     municipality scheduled_service gps_code iata_code  \
# 37         US-NY      Beekmantown                no     00NK       NaN
# 39         US-NY  West Bloomfield                no     00NY       NaN
# 110        US-NY     Poughkeepsie                no     01NY       NaN
# 177        US-NY      Durhamville                no     02NY       NaN
# 245        US-NY        Riverhead                no     03NY       NaN
# ...          ...              ...               ...      ...       ...
# 71515      US-NY           Ramapo                no     29NY       NaN
# 71545      US-NY          Massena                no     36NY       NaN
# 71556      US-NY            Utica                no     NY86       NaN
# 71565      US-NY         Bethpage                no      NaN       NaN
# 73133      US-NY       Round Lake                no      W57       NaN
#
#       local_code                                          home_link  \
# 37          00NK                                                NaN
# 39          00NY                                                NaN
# 110         01NY                                                NaN
# 177         02NY                                                NaN
# 245         03NY                                                NaN
# ...          ...                                                ...
# 71515       29NY                                                NaN
# 71545       36NY                                                NaN
# 71556       NY86                                                NaN
# 71565        NaN                                                NaN
# 73133        W57  https://www.dot.ny.gov/divisions/operating/opd...
#
#       wikipedia_link  keywords
# 37               NaN       NaN
# 39               NaN       NaN
# 110              NaN       NaN
# 177              NaN       NaN
# 245              NaN       NaN
# ...              ...       ...
# 71515            NaN       NaN
# 71545            NaN       NaN
# 71556            NaN       NaN
# 71565            NaN  BPA, BPA
# 73133            NaN      NY46
#
# [781 rows x 18 columns]

# %%
# set(airports['type'].values)

# %%
# airports['type'].unique()
airports['type'].value_counts()
# Out:
# small_airport     39964
# heliport          19732
# closed            10880
# medium_airport     4763
# seaplane_base      1166
# large_airport       470
# balloonport          49
# Name: type, dtype: int64

# %%
airports_NY_large = airports[(airports['iso_region'] == "US-NY") & (airports['type'] == 'large_airport')]

# %%
airports_NY_large
# Out:
#          id ident           type                                    name  \
# 35591  3431  KBUF  large_airport   Buffalo Niagara International Airport
# 37009  3622  KJFK  large_airport    John F Kennedy International Airport
# 37150  3643  KLGA  large_airport                      La Guardia Airport
# 39419  3913  KSYR  large_airport  Syracuse Hancock International Airport
#
#        latitude_deg  longitude_deg  elevation_ft continent iso_country  \
# 35591     42.940498     -78.732201         728.0       NaN          US
# 37009     40.639447     -73.779317          13.0       NaN          US
# 37150     40.777199     -73.872597          21.0       NaN          US
# 39419     43.111198     -76.106300         421.0       NaN          US
#
#       iso_region municipality scheduled_service gps_code iata_code local_code  \
# 35591      US-NY      Buffalo               yes     KBUF       BUF        BUF
# 37009      US-NY     New York               yes     KJFK       JFK        JFK
# 37150      US-NY     New York               yes     KLGA       LGA        LGA
# 39419      US-NY     Syracuse               yes     KSYR       SYR        SYR
#
#                                home_link  \
# 35591                                NaN
# 37009        https://www.jfkairport.com/
# 37150  https://www.laguardiaairport.com/
# 39419         http://www.syrairport.org/
#
#                                           wikipedia_link  \
# 35591  https://en.wikipedia.org/wiki/Buffalo_Niagara_...
# 37009  https://en.wikipedia.org/wiki/John_F._Kennedy_...
# 37150    https://en.wikipedia.org/wiki/LaGuardia_Airport
# 39419  https://en.wikipedia.org/wiki/Syracuse_Hancock...
#
#                                                 keywords
# 35591                                                NaN
# 37009  Manhattan, New York City, NYC, Idlewild, IDL, ...
# 37150  Manhattan, New York City, NYC, Glenn H. Curtis...
# 39419                                                NaN

# %%
# Extract the name, identification code, and municipality of
# all airports with ISO region "US-NY" and type "large_airport"

airports_NY_large[["name", "ident", "municipality"]].reset_index(drop=True) # reset index to remove original line numbers
# Out:
#                                      name ident municipality
# 0   Buffalo Niagara International Airport  KBUF      Buffalo
# 1    John F Kennedy International Airport  KJFK     New York
# 2                      La Guardia Airport  KLGA     New York
# 3  Syracuse Hancock International Airport  KSYR     Syracuse

# %% [markdown]
# #### 2. Sorting

# %%
# From airport_freq, extract all communication frequencies for KJFK,
# with frequencies sorted in ascending order

airport_freq.head()
# Out:
#        id  airport_ref airport_ident   type          description  \
# 0   70518         6528          00CA   CTAF                 CTAF
# 1  307581         6589          01FL  ARCAL                  NaN
# 2   75239         6589          01FL   CTAF  CEDAR KNOLL TRAFFIC
# 3   60191         6756          04CA   CTAF                 CTAF
# 4   59287         6779          04MS   UNIC               UNICOM
#
#    frequency_mhz
# 0          122.9
# 1          122.9
# 2          122.8
# 3          122.9
# 4          122.8

# %%
# Since we have already known the IDs of NY airports,
# let's use the id columns to extract NY-related frequencies.
airport_freq[airport_freq['airport_ref'] == 3622]
# Out:
#            id  airport_ref airport_ident  type                description  \
# 11898   69293         3622          KJFK   APP       NEW YORK APP (ROBER)
# 11899  301312         3622          KJFK   APP  NEW YORK APPROACH (CAMRN)
# 11900  301313         3622          KJFK   APP  NEW YORK APPROACH (FINAL)
# 11901   69294         3622          KJFK  ATIS                       ATIS
# 11902   69295         3622          KJFK   CLD                   CLNC DEL
# 11903   69296         3622          KJFK   DEP               NEW YORK DEP
# 11904  332895         3622          KJFK   GND                    GND ALT
# 11905   69297         3622          KJFK   GND                        GND
# 11906   69298         3622          KJFK   RDO               NEW YORK RDO
# 11907   69299         3622          KJFK   TWR                KENNEDY TWR
# 11908  332894         3622          KJFK   TWR                    TWR ALT
# 11909   69300         3622          KJFK  UNIC                     UNICOM
#
#        frequency_mhz
# 11898         125.70
# 11899         127.40
# 11900         132.40
# 11901         115.10
# 11902         135.05
# 11903         135.90
# 11904         121.65
# 11905         121.90
# 11906         115.90
# 11907         119.10
# 11908         123.90
# 11909         122.95

# %%
KJFK_freq = airport_freq[airport_freq['airport_ident'] == 'KJFK']
KJFK_freq
# Out:
#            id  airport_ref airport_ident  type                description  \
# 11898   69293         3622          KJFK   APP       NEW YORK APP (ROBER)
# 11899  301312         3622          KJFK   APP  NEW YORK APPROACH (CAMRN)
# 11900  301313         3622          KJFK   APP  NEW YORK APPROACH (FINAL)
# 11901   69294         3622          KJFK  ATIS                       ATIS
# 11902   69295         3622          KJFK   CLD                   CLNC DEL
# 11903   69296         3622          KJFK   DEP               NEW YORK DEP
# 11904  332895         3622          KJFK   GND                    GND ALT
# 11905   69297         3622          KJFK   GND                        GND
# 11906   69298         3622          KJFK   RDO               NEW YORK RDO
# 11907   69299         3622          KJFK   TWR                KENNEDY TWR
# 11908  332894         3622          KJFK   TWR                    TWR ALT
# 11909   69300         3622          KJFK  UNIC                     UNICOM
#
#        frequency_mhz
# 11898         125.70
# 11899         127.40
# 11900         132.40
# 11901         115.10
# 11902         135.05
# 11903         135.90
# 11904         121.65
# 11905         121.90
# 11906         115.90
# 11907         119.10
# 11908         123.90
# 11909         122.95

# %%
KJFK_freq.sort_values(by="frequency_mhz")
# Out:
#            id  airport_ref airport_ident  type                description  \
# 11901   69294         3622          KJFK  ATIS                       ATIS
# 11906   69298         3622          KJFK   RDO               NEW YORK RDO
# 11907   69299         3622          KJFK   TWR                KENNEDY TWR
# 11904  332895         3622          KJFK   GND                    GND ALT
# 11905   69297         3622          KJFK   GND                        GND
# 11909   69300         3622          KJFK  UNIC                     UNICOM
# 11908  332894         3622          KJFK   TWR                    TWR ALT
# 11898   69293         3622          KJFK   APP       NEW YORK APP (ROBER)
# 11899  301312         3622          KJFK   APP  NEW YORK APPROACH (CAMRN)
# 11900  301313         3622          KJFK   APP  NEW YORK APPROACH (FINAL)
# 11902   69295         3622          KJFK   CLD                   CLNC DEL
# 11903   69296         3622          KJFK   DEP               NEW YORK DEP
#
#        frequency_mhz
# 11901         115.10
# 11906         115.90
# 11907         119.10
# 11904         121.65
# 11905         121.90
# 11909         122.95
# 11908         123.90
# 11898         125.70
# 11899         127.40
# 11900         132.40
# 11902         135.05
# 11903         135.90

# %%
# From airport_freq, extract all communication frequencies for KJFK,
# with frequencies sorted in descending order

KJFK_freq.sort_values(by="frequency_mhz", ascending=False)
# Out:
#            id  airport_ref airport_ident  type                description  \
# 11903   69296         3622          KJFK   DEP               NEW YORK DEP
# 11902   69295         3622          KJFK   CLD                   CLNC DEL
# 11900  301313         3622          KJFK   APP  NEW YORK APPROACH (FINAL)
# 11899  301312         3622          KJFK   APP  NEW YORK APPROACH (CAMRN)
# 11898   69293         3622          KJFK   APP       NEW YORK APP (ROBER)
# 11908  332894         3622          KJFK   TWR                    TWR ALT
# 11909   69300         3622          KJFK  UNIC                     UNICOM
# 11905   69297         3622          KJFK   GND                        GND
# 11904  332895         3622          KJFK   GND                    GND ALT
# 11907   69299         3622          KJFK   TWR                KENNEDY TWR
# 11906   69298         3622          KJFK   RDO               NEW YORK RDO
# 11901   69294         3622          KJFK  ATIS                       ATIS
#
#        frequency_mhz
# 11903         135.90
# 11902         135.05
# 11900         132.40
# 11899         127.40
# 11898         125.70
# 11908         123.90
# 11909         122.95
# 11905         121.90
# 11904         121.65
# 11907         119.10
# 11906         115.90
# 11901         115.10

# %%
# Find the five rows with larget frequency value from the previous data frame

KJFK_freq.head() # by default head() returns the first 5 rows

# %% [markdown]
# #### 3. Filter on a list of values

# %%
# Create a data frame including all communication frequencies
# used by NY large airports
airport_ids = airports_NY_large['id']
airport_ids.values

for index in airport_ids:
    print(airport_freq[airport_freq['airport_ref'] == index])
# Out:
#          id  airport_ref airport_ident  type      description  frequency_mhz
# 7982  69857         3431          KBUF   A/D  Buffalo APP/DEP         126.15
# 7983  69858         3431          KBUF  ATIS             ATIS         135.35
# 7984  69859         3431          KBUF   CLD         CLNC DEL         124.70
# 7985  69860         3431          KBUF   GND              GND         133.20
# 7986  69861         3431          KBUF   RDO              RDO         122.60
# 7987  69862         3431          KBUF   TWR              TWR         120.50
#            id  airport_ref airport_ident  type                description  \
# 11898   69293         3622          KJFK   APP       NEW YORK APP (ROBER)
# 11899  301312         3622          KJFK   APP  NEW YORK APPROACH (CAMRN)
# 11900  301313         3622          KJFK   APP  NEW YORK APPROACH (FINAL)
# 11901   69294         3622          KJFK  ATIS                       ATIS
# 11902   69295         3622          KJFK   CLD                   CLNC DEL
# 11903   69296         3622          KJFK   DEP               NEW YORK DEP
# 11904  332895         3622          KJFK   GND                    GND ALT
# 11905   69297         3622          KJFK   GND                        GND
# 11906   69298         3622          KJFK   RDO               NEW YORK RDO
# 11907   69299         3622          KJFK   TWR                KENNEDY TWR
# 11908  332894         3622          KJFK   TWR                    TWR ALT
# 11909   69300         3622          KJFK  UNIC                     UNICOM
#
#        frequency_mhz
# 11898         125.70
# 11899         127.40
# 11900         132.40
# 11901         115.10
# 11902         135.05
# 11903         135.90
# 11904         121.65
# 11905         121.90
# 11906         115.90
# 11907         119.10
# 11908         123.90
# 11909         122.95
#           id  airport_ref airport_ident  type   description  frequency_mhz
# 12335  66553         3643          KLGA   APP  NEW YORK APP        118.000
# 12336  66554         3643          KLGA   APP  NEW YORK APP        132.700
# 12337  66555         3643          KLGA  ATIS          ATIS        125.950
# 12338  66556         3643          KLGA   CLD      CLNC DEL        121.875
# 12339  66557         3643          KLGA   DEP  NEW YORK DEP        120.400
# 12340  66558         3643          KLGA   GND           GND        121.700
# 12341  66559         3643          KLGA   TWR           TWR        118.700
# 12342  66560         3643          KLGA  UNIC        UNICOM        122.950
#           id  airport_ref airport_ident  type description  frequency_mhz
# 16576  68023         3913          KSYR   A/D     APP/DEP        126.125
# 16577  68024         3913          KSYR  ATIS        ATIS        132.050
# 16578  68025         3913          KSYR   CLD    CLNC DEL        125.050
# 16579  68026         3913          KSYR   GND         GND        121.700
# 16580  68027         3913          KSYR   OPS     ANG OPS        139.625
# 16581  68028         3913          KSYR   TWR         TWR        120.300
# 16582  68029         3913          KSYR  UNIC      UNICOM        122.950

# %%
# Extract all communication frequencies used for a large airport in New York state

freq_NY_airports = pd.DataFrame()

for ident in airports_NY_large['ident']:
#     print(ident) # verify that the identification codes are extracted correctly
    freq_airport = airport_freq[airport_freq['airport_ident'] == ident]
#     print(freq_airport) # verify that the frequencies are extracted correctly
    freq_NY_airports = pd.concat([freq_NY_airports, freq_airport])

freq_NY_airports
# Out:
#            id  airport_ref airport_ident  type                description  \
# 7982    69857         3431          KBUF   A/D            Buffalo APP/DEP
# 7983    69858         3431          KBUF  ATIS                       ATIS
# 7984    69859         3431          KBUF   CLD                   CLNC DEL
# 7985    69860         3431          KBUF   GND                        GND
# 7986    69861         3431          KBUF   RDO                        RDO
# 7987    69862         3431          KBUF   TWR                        TWR
# 11898   69293         3622          KJFK   APP       NEW YORK APP (ROBER)
# 11899  301312         3622          KJFK   APP  NEW YORK APPROACH (CAMRN)
# 11900  301313         3622          KJFK   APP  NEW YORK APPROACH (FINAL)
# 11901   69294         3622          KJFK  ATIS                       ATIS
# 11902   69295         3622          KJFK   CLD                   CLNC DEL
# 11903   69296         3622          KJFK   DEP               NEW YORK DEP
# 11904  332895         3622          KJFK   GND                    GND ALT
# 11905   69297         3622          KJFK   GND                        GND
# 11906   69298         3622          KJFK   RDO               NEW YORK RDO
# 11907   69299         3622          KJFK   TWR                KENNEDY TWR
# 11908  332894         3622          KJFK   TWR                    TWR ALT
# 11909   69300         3622          KJFK  UNIC                     UNICOM
# 12335   66553         3643          KLGA   APP               NEW YORK APP
# 12336   66554         3643          KLGA   APP               NEW YORK APP
# 12337   66555         3643          KLGA  ATIS                       ATIS
# 12338   66556         3643          KLGA   CLD                   CLNC DEL
# 12339   66557         3643          KLGA   DEP               NEW YORK DEP
# 12340   66558         3643          KLGA   GND                        GND
# 12341   66559         3643          KLGA   TWR                        TWR
# 12342   66560         3643          KLGA  UNIC                     UNICOM
# 16576   68023         3913          KSYR   A/D                    APP/DEP
# 16577   68024         3913          KSYR  ATIS                       ATIS
# 16578   68025         3913          KSYR   CLD                   CLNC DEL
# 16579   68026         3913          KSYR   GND                        GND
# 16580   68027         3913          KSYR   OPS                    ANG OPS
# 16581   68028         3913          KSYR   TWR                        TWR
# 16582   68029         3913          KSYR  UNIC                     UNICOM
#
#        frequency_mhz
# 7982         126.150
# 7983         135.350
# 7984         124.700
# 7985         133.200
# 7986         122.600
# 7987         120.500
# 11898        125.700
# 11899        127.400
# 11900        132.400
# 11901        115.100
# 11902        135.050
# 11903        135.900
# 11904        121.650
# 11905        121.900
# 11906        115.900
# 11907        119.100
# 11908        123.900
# 11909        122.950
# 12335        118.000
# 12336        132.700
# 12337        125.950
# 12338        121.875
# 12339        120.400
# 12340        121.700
# 12341        118.700
# 12342        122.950
# 16576        126.125
# 16577        132.050
# 16578        125.050
# 16579        121.700
# 16580        139.625
# 16581        120.300
# 16582        122.950

# %%
idents = airports_NY_large['ident']
filter1 = airport_freq['airport_ident'].isin(idents)
airport_freq[filter1]
# Out:
#            id  airport_ref airport_ident  type                description  \
# 7982    69857         3431          KBUF   A/D            Buffalo APP/DEP
# 7983    69858         3431          KBUF  ATIS                       ATIS
# 7984    69859         3431          KBUF   CLD                   CLNC DEL
# 7985    69860         3431          KBUF   GND                        GND
# 7986    69861         3431          KBUF   RDO                        RDO
# 7987    69862         3431          KBUF   TWR                        TWR
# 11898   69293         3622          KJFK   APP       NEW YORK APP (ROBER)
# 11899  301312         3622          KJFK   APP  NEW YORK APPROACH (CAMRN)
# 11900  301313         3622          KJFK   APP  NEW YORK APPROACH (FINAL)
# 11901   69294         3622          KJFK  ATIS                       ATIS
# 11902   69295         3622          KJFK   CLD                   CLNC DEL
# 11903   69296         3622          KJFK   DEP               NEW YORK DEP
# 11904  332895         3622          KJFK   GND                    GND ALT
# 11905   69297         3622          KJFK   GND                        GND
# 11906   69298         3622          KJFK   RDO               NEW YORK RDO
# 11907   69299         3622          KJFK   TWR                KENNEDY TWR
# 11908  332894         3622          KJFK   TWR                    TWR ALT
# 11909   69300         3622          KJFK  UNIC                     UNICOM
# 12335   66553         3643          KLGA   APP               NEW YORK APP
# 12336   66554         3643          KLGA   APP               NEW YORK APP
# 12337   66555         3643          KLGA  ATIS                       ATIS
# 12338   66556         3643          KLGA   CLD                   CLNC DEL
# 12339   66557         3643          KLGA   DEP               NEW YORK DEP
# 12340   66558         3643          KLGA   GND                        GND
# 12341   66559         3643          KLGA   TWR                        TWR
# 12342   66560         3643          KLGA  UNIC                     UNICOM
# 16576   68023         3913          KSYR   A/D                    APP/DEP
# 16577   68024         3913          KSYR  ATIS                       ATIS
# 16578   68025         3913          KSYR   CLD                   CLNC DEL
# 16579   68026         3913          KSYR   GND                        GND
# 16580   68027         3913          KSYR   OPS                    ANG OPS
# 16581   68028         3913          KSYR   TWR                        TWR
# 16582   68029         3913          KSYR  UNIC                     UNICOM
#
#        frequency_mhz
# 7982         126.150
# 7983         135.350
# 7984         124.700
# 7985         133.200
# 7986         122.600
# 7987         120.500
# 11898        125.700
# 11899        127.400
# 11900        132.400
# 11901        115.100
# 11902        135.050
# 11903        135.900
# 11904        121.650
# 11905        121.900
# 11906        115.900
# 11907        119.100
# 11908        123.900
# 11909        122.950
# 12335        118.000
# 12336        132.700
# 12337        125.950
# 12338        121.875
# 12339        120.400
# 12340        121.700
# 12341        118.700
# 12342        122.950
# 16576        126.125
# 16577        132.050
# 16578        125.050
# 16579        121.700
# 16580        139.625
# 16581        120.300
# 16582        122.950

# %%
airport_freq[airport_freq['airport_ident'].isin(airports_NY_large['ident'])]
# Out:
#            id  airport_ref airport_ident  type                description  \
# 7982    69857         3431          KBUF   A/D            Buffalo APP/DEP
# 7983    69858         3431          KBUF  ATIS                       ATIS
# 7984    69859         3431          KBUF   CLD                   CLNC DEL
# 7985    69860         3431          KBUF   GND                        GND
# 7986    69861         3431          KBUF   RDO                        RDO
# 7987    69862         3431          KBUF   TWR                        TWR
# 11898   69293         3622          KJFK   APP       NEW YORK APP (ROBER)
# 11899  301312         3622          KJFK   APP  NEW YORK APPROACH (CAMRN)
# 11900  301313         3622          KJFK   APP  NEW YORK APPROACH (FINAL)
# 11901   69294         3622          KJFK  ATIS                       ATIS
# 11902   69295         3622          KJFK   CLD                   CLNC DEL
# 11903   69296         3622          KJFK   DEP               NEW YORK DEP
# 11904  332895         3622          KJFK   GND                    GND ALT
# 11905   69297         3622          KJFK   GND                        GND
# 11906   69298         3622          KJFK   RDO               NEW YORK RDO
# 11907   69299         3622          KJFK   TWR                KENNEDY TWR
# 11908  332894         3622          KJFK   TWR                    TWR ALT
# 11909   69300         3622          KJFK  UNIC                     UNICOM
# 12335   66553         3643          KLGA   APP               NEW YORK APP
# 12336   66554         3643          KLGA   APP               NEW YORK APP
# 12337   66555         3643          KLGA  ATIS                       ATIS
# 12338   66556         3643          KLGA   CLD                   CLNC DEL
# 12339   66557         3643          KLGA   DEP               NEW YORK DEP
# 12340   66558         3643          KLGA   GND                        GND
# 12341   66559         3643          KLGA   TWR                        TWR
# 12342   66560         3643          KLGA  UNIC                     UNICOM
# 16576   68023         3913          KSYR   A/D                    APP/DEP
# 16577   68024         3913          KSYR  ATIS                       ATIS
# 16578   68025         3913          KSYR   CLD                   CLNC DEL
# 16579   68026         3913          KSYR   GND                        GND
# 16580   68027         3913          KSYR   OPS                    ANG OPS
# 16581   68028         3913          KSYR   TWR                        TWR
# 16582   68029         3913          KSYR  UNIC                     UNICOM
#
#        frequency_mhz
# 7982         126.150
# 7983         135.350
# 7984         124.700
# 7985         133.200
# 7986         122.600
# 7987         120.500
# 11898        125.700
# 11899        127.400
# 11900        132.400
# 11901        115.100
# 11902        135.050
# 11903        135.900
# 11904        121.650
# 11905        121.900
# 11906        115.900
# 11907        119.100
# 11908        123.900
# 11909        122.950
# 12335        118.000
# 12336        132.700
# 12337        125.950
# 12338        121.875
# 12339        120.400
# 12340        121.700
# 12341        118.700
# 12342        122.950
# 16576        126.125
# 16577        132.050
# 16578        125.050
# 16579        121.700
# 16580        139.625
# 16581        120.300
# 16582        122.950

# %% [markdown]
# #### 4. Grouping

# %%
countries.head()
# Out:
#        id code                  name continent  \
# 0  302672   AD               Andorra        EU
# 1  302618   AE  United Arab Emirates        AS
# 2  302619   AF           Afghanistan        AS
# 3  302722   AG   Antigua and Barbuda       NaN
# 4  302723   AI              Anguilla       NaN
#
#                                       wikipedia_link  \
# 0              https://en.wikipedia.org/wiki/Andorra
# 1  https://en.wikipedia.org/wiki/United_Arab_Emir...
# 2          https://en.wikipedia.org/wiki/Afghanistan
# 3  https://en.wikipedia.org/wiki/Antigua_and_Barbuda
# 4             https://en.wikipedia.org/wiki/Anguilla
#
#                                  keywords
# 0                       Andorran airports
# 1  UAE,مطارات في الإمارات العربية المتحدة
# 2                                     NaN
# 3                       Antiguan airports
# 4                                     NaN

# %%
airports.head()
# Out:
#        id ident           type                  name  latitude_deg  \
# 0    6523   00A       heliport     Total RF Heliport     40.070985
# 1  323361  00AA  small_airport  Aero B Ranch Airport     38.704022
# 2    6524  00AK  small_airport          Lowell Field     59.947733
# 3    6525  00AL  small_airport          Epps Airpark     34.864799
# 4  506791  00AN  small_airport  Katmai Lodge Airport     59.093287
#
#    longitude_deg  elevation_ft continent iso_country iso_region  municipality  \
# 0     -74.933689          11.0       NaN          US      US-PA      Bensalem
# 1    -101.473911        3435.0       NaN          US      US-KS         Leoti
# 2    -151.692524         450.0       NaN          US      US-AK  Anchor Point
# 3     -86.770302         820.0       NaN          US      US-AL       Harvest
# 4    -156.456699          80.0       NaN          US      US-AK   King Salmon
#
#   scheduled_service gps_code iata_code local_code  \
# 0                no     K00A       NaN        00A
# 1                no     00AA       NaN       00AA
# 2                no     00AK       NaN       00AK
# 3                no     00AL       NaN       00AL
# 4                no     00AN       NaN       00AN
#
#                                            home_link wikipedia_link keywords
# 0  https://www.penndot.pa.gov/TravelInPA/airports...            NaN      NaN
# 1                                                NaN            NaN      NaN
# 2                                                NaN            NaN      NaN
# 3                                                NaN            NaN      NaN
# 4                                                NaN            NaN      NaN

# %%
# Calculate the number of large airports for each country

airports_by_country = pd.DataFrame()

for country_code in countries['code']:
    # extract the large airports from that country
    large_airports_country = airports[(airports['iso_country'] == country_code) & (airports['type'] == "large_airport")]
#     print(large_airports_country)
    # count the number of large airports
    num_large_airport = large_airports_country.shape[0]

    # add a row in airports_by_country with the country name and the number of large airports
    airports_by_country.loc[country_code, 'Number of Large Airports'] = num_large_airport

airports_by_country
# Out:
#     Number of Large Airports
# AD                       0.0
# AE                       4.0
# AF                       0.0
# AG                       0.0
# AI                       0.0
# ..                       ...
# YT                       0.0
# ZA                       3.0
# ZM                       1.0
# ZW                       1.0
# ZZ                       0.0
#
# [248 rows x 1 columns]

# %%
large_airports = airports[airports['type'] == 'large_airport']
# large_airports.head()
large_airports.groupby('iso_country').size().to_frame("Number of Large Airports")
# Out:
#              Number of Large Airports
# iso_country
# AE                                  4
# AL                                  1
# AM                                  1
# AO                                  1
# AR                                  2
# ...                               ...
# VN                                  2
# VU                                  1
# ZA                                  3
# ZM                                  1
# ZW                                  1
#
# [159 rows x 1 columns]

# %%
# Alternatively, split the records by country and type
airport_counts = airports.groupby(['iso_country', 'type']).size().unstack()
results = airport_counts[['large_airport']].copy()
results.head()
# Out:
# type         large_airport
# iso_country
# AD                     NaN
# AE                     4.0
# AF                     NaN
# AG                     NaN
# AI                     NaN

# %%
# An interesting challenge is to convert all NaNs to 0.
for index in results.index:
    # if the large_airport value is NaN, change it to 0.
    if pd.isnull(results.loc[index, 'large_airport']):
        results.loc[index, 'large_airport'] = 0
results.head(10)
# Out:
# type         large_airport
# iso_country
# AD                     0.0
# AE                     4.0
# AF                     0.0
# AG                     0.0
# AI                     0.0
# AL                     1.0
# AM                     1.0
# AO                     1.0
# AQ                     0.0
# AR                     2.0

# %%
results = results.fillna(0)
results.head(10)
# Out:
# type         large_airport
# iso_country
# AD                     0.0
# AE                     4.0
# AF                     0.0
# AG                     0.0
# AI                     0.0
# AL                     1.0
# AM                     1.0
# AO                     1.0
# AQ                     0.0
# AR                     2.0

# %%
# Add country names to the results
# countries.head()
final_results = pd.merge(results, countries, left_index=True, 
                         right_on='code', how='left')
final_results.head()
# Out:
#    large_airport      id code                  name continent  \
# 0            0.0  302672   AD               Andorra        EU
# 1            4.0  302618   AE  United Arab Emirates        AS
# 2            0.0  302619   AF           Afghanistan        AS
# 3            0.0  302722   AG   Antigua and Barbuda       NaN
# 4            0.0  302723   AI              Anguilla       NaN
#
#                                       wikipedia_link  \
# 0              https://en.wikipedia.org/wiki/Andorra
# 1  https://en.wikipedia.org/wiki/United_Arab_Emir...
# 2          https://en.wikipedia.org/wiki/Afghanistan
# 3  https://en.wikipedia.org/wiki/Antigua_and_Barbuda
# 4             https://en.wikipedia.org/wiki/Anguilla
#
#                                  keywords
# 0                       Andorran airports
# 1  UAE,مطارات في الإمارات العربية المتحدة
# 2                                     NaN
# 3                       Antiguan airports
# 4                                     NaN

# %%
final_results = final_results[['name', 'large_airport']]
final_results.head(10)
# Out:
#                    name  large_airport
# 0               Andorra            0.0
# 1  United Arab Emirates            4.0
# 2           Afghanistan            0.0
# 3   Antigua and Barbuda            0.0
# 4              Anguilla            0.0
# 5               Albania            1.0
# 6               Armenia            1.0
# 7                Angola            1.0
# 8            Antarctica            0.0
# 9             Argentina            2.0

# %%
# Alternatively, drop the unwanted columns before merging
final_results = pd.merge(results, countries[['code', 'name']], left_index=True, 
                         right_on='code', how='left')
final_results.drop('code', inplace=True, axis=1)
final_results.head()
# Out:
#    large_airport                  name
# 0            0.0               Andorra
# 1            4.0  United Arab Emirates
# 2            0.0           Afghanistan
# 3            0.0   Antigua and Barbuda
# 4            0.0              Anguilla

# %%
# Find the top 5 countries having the largest amount of large airports

final_results.sort_values('large_airport', ascending=False).head(10)
# Out:
#      large_airport           name
# 229           67.0  United States
# 45            39.0          China
# 188           16.0         Russia
# 154           16.0         Mexico
# 107           14.0          Italy
# 35            13.0         Canada
# 111           12.0          Japan
# 65            11.0          Spain
# 29            10.0         Brazil
# 102           10.0          India

# %% [markdown]
# #### 5. Merging

# %%
# Merge the above result with countries data frame to find the name of the countries

# %%
# Append full country name and region name to airports.
